# %% [markdown]
# # Simulation des Scénarios Futurs - UBEM Résidentiel Québec
#
# Ce notebook permet de simuler tous les scénarios futurs (2035 et 2050) pour le modèle UBEM Résidentiel Québec. Il offre la possibilité de lancer des simulations individuelles ou en batch pour tous les scénarios disponibles.
#
# ## Structure des scénarios
#
# Les scénarios sont organisés selon la nomenclature suivante :
# ```
# {année}_{type_climat}_{croissance_électrification}_{efficacité}
# ```
#
# - **Année** : 2035 ou 2050
# - **Type de climat** : warm (chaud), typical (normal), cold (froid)
# - **Croissance et électrification** : PV (Projection Verte), UB (Ultra Bas carbone)
# - **Efficacité** : E (standard), EE (maximale)
#
# Par exemple : **2035_warm_PV_E** représente un scénario pour 2035 avec un climat chaud, une projection verte standard et une efficacité standard.

# %%
# Imports des modules nécessaires
import os
import sys
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path
from datetime import datetime
import subprocess
from IPython.display import display, HTML, clear_output

# Ajouter le chemin du projet pour importer les modules
project_root = Path().absolute().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# Imports des modules du projet
from src.config import config

# %% [markdown]
# ## Configuration et Initialisation

# %%
# Afficher tous les scénarios disponibles
print("Scénarios disponibles :")
for scenario in config.future_scenarios.SCENARIOS:
    description = config.future_scenarios.SCENARIO_NAMES.get(scenario, scenario)
    print(f"- {scenario}: {description}")
# Out:
# Scénarios disponibles :
# - 2035_warm_PV_E: 2035 - Année chaude - Projection verte - Efficacité standard
# - 2035_warm_PV_EE: 2035 - Année chaude - Projection verte - Efficacité maximale
# - 2035_warm_UB_E: 2035 - Année chaude - Ultra bas carbone - Efficacité standard
# - 2035_warm_UB_EE: 2035 - Année chaude - Ultra bas carbone - Efficacité maximale
# - 2035_typical_PV_E: 2035 - Année normale - Projection verte - Efficacité standard
# - 2035_typical_PV_EE: 2035 - Année normale - Projection verte - Efficacité maximale
# - 2035_typical_UB_E: 2035 - Année normale - Ultra bas carbone - Efficacité standard
# - 2035_typical_UB_EE: 2035 - Année normale - Ultra bas carbone - Efficacité maximale
# - 2035_cold_PV_E: 2035 - Année froide - Projection verte - Efficacité standard
# - 2035_cold_PV_EE: 2035 - Année froide - Projection verte - Efficacité maximale
# - 2035_cold_UB_E: 2035 - Année froide - Ultra bas carbone - Efficacité standard
# - 2035_cold_UB_EE: 2035 - Année froide - Ultra bas carbone - Efficacité maximale
# - 2050_warm_PV_E: 2050 - Année chaude - Projection verte - Efficacité standard
# - 2050_warm_PV_EE: 2050 - Année chaude - Projection verte - Efficacité maximale
# - 2050_warm_UB_E: 2050 - Année chaude - Ultra bas carbone - Efficacité standard
# - 2050_warm_UB_EE: 2050 - Année chaude - Ultra bas carbone - Efficacité maximale
# - 2050_typical_PV_E: 2050 - Année normale - Projection verte - Efficacité standard
# - 2050_typical_PV_EE: 2050 - Année normale - Projection verte - Efficacité maximale
# - 2050_typical_UB_E: 2050 - Année normale - Ultra bas carbone - Efficacité standard
# - 2050_typical_UB_EE: 2050 - Année normale - Ultra bas carbone - Efficacité maximale
# - 2050_cold_PV_E: 2050 - Année froide - Projection verte - Efficacité standard
# - 2050_cold_PV_EE: 2050 - Année froide - Projection verte - Efficacité maximale
# - 2050_cold_UB_E: 2050 - Année froide - Ultra bas carbone - Efficacité standard
# - 2050_cold_UB_EE: 2050 - Année froide - Ultra bas carbone - Efficacité maximale

# %%
# Fonction pour exécuter une simulation pour un scénario donné
def run_simulation(scenario_key, verbose=True):
    """Exécute une simulation pour un scénario futur donné.
    
    Args:
        scenario_key: Clé du scénario (ex: '2035_warm_PV_E')
        verbose: Si True, affiche la sortie en temps réel
        
    Returns:
        Tuple (success, output) indiquant si la simulation a réussi et la sortie
    """
    # Vérifier que le scénario est valide
    if scenario_key not in config.future_scenarios.SCENARIOS:
        print(f"Erreur: Scénario {scenario_key} non valide")
        return False, f"Scénario {scenario_key} non valide"
    
    # Préparer la commande
    cmd = [sys.executable, "-m", "src.main", "simulate", "--future-scenario", scenario_key]
    start_time = time.time()
    
    # Exécuter la commande
    print(f"Démarrage de la simulation pour {scenario_key}...")
    process = subprocess.Popen(
        cmd, 
        stdout=subprocess.PIPE, 
        stderr=subprocess.STDOUT,
        cwd=project_root,
        universal_newlines=True
    )
    
    # Capture de la sortie
    output_lines = []
    for line in process.stdout:
        output_lines.append(line.rstrip())
        if verbose:
            print(line.rstrip())
    
    # Attendre la fin du processus
    process.wait()
    end_time = time.time()
    duration = end_time - start_time
    
    # Vérifier le résultat
    success = process.returncode == 0
    status = "Réussie" if success else "Échouée"
    
    print(f"Simulation {status} pour {scenario_key} en {duration:.1f} secondes")
    return success, "\n".join(output_lines)

# %%
# Fonction pour exécuter plusieurs simulations en séquence
def run_multiple_simulations(scenarios, verbose=False):
    """Exécute plusieurs simulations en séquence.
    
    Args:
        scenarios: Liste des scénarios à simuler
        verbose: Si True, affiche la sortie en temps réel
        
    Returns:
        Dictionnaire des résultats {scenario: (success, output)}
    """
    results = {}
    start_time = time.time()
    
    for i, scenario in enumerate(scenarios, 1):
        print(f"\n[{i}/{len(scenarios)}] Simulation du scénario {scenario}")
        success, output = run_simulation(scenario, verbose=verbose)
        results[scenario] = (success, output)
        
        # Afficher un résumé après chaque simulation
        if not verbose:
            status = "✅ Réussie" if success else "❌ Échouée"
            print(f"{status}: {scenario}")
    
    # Afficher un résumé final
    end_time = time.time()
    total_duration = end_time - start_time
    success_count = sum(1 for success, _ in results.values() if success)
    
    print(f"\nRésumé des simulations:")
    print(f"- Nombre total de simulations: {len(scenarios)}")
    print(f"- Simulations réussies: {success_count}")
    print(f"- Simulations échouées: {len(scenarios) - success_count}")
    print(f"- Durée totale: {total_duration:.1f} secondes ({total_duration/60:.1f} minutes)")
    
    return results

# %% [markdown]
# ## 1. Simulation individuelle
#
# Cette section permet de simuler un scénario futur spécifique.

# %%
# Sélectionner un scénario et l'exécuter
scenario_key = "2050_cold_UB_E"  # À modifier selon le scénario souhaité
success, output = run_simulation(scenario_key, verbose=True)
# Out:
# Démarrage de la simulation pour 2050_cold_UB_E...
# 2025-04-07 17:26:50,291 - src.calibration.transfer_learning_manager - INFO - Base de connaissances chargÃ©e avec 3 entrÃ©es
# 2025-04-07 17:26:50,291 - src.calibration.transfer_learning_manager - INFO - Chargement du modÃ¨le de transfert existant
# 2025-04-07 17:26:50,298 - src.calibration.transfer_learning_manager - INFO - ModÃ¨le de transfert chargÃ© avec succÃ¨s
# 2025-04-07 17:26:50315 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:26:50318 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:26:50318 - src.managers.simulation_manager - INFO - Tentative de chargement des paramÃ¨tres de calibration pour l'annÃ©e 2023
# 2025-04-07 17:26:50318 - src.managers.simulation_manager - INFO - RÃ©pertoire de calibration: c:\PI4\6\residence_quebec\data\outputs\calibration\2023
# 2025-04-07 17:26:50703 - src.managers.simulation_manager - INFO - Fichier de rÃ©sultats de calibration le plus rÃ©cent: c:\PI4\6\residence_quebec\data\outputs\calibration\2023\20250403_104404\calibration_results.json
# 2025-04-07 17:26:50703 - src.managers.simulation_manager - INFO - ParamÃ¨tres calibrÃ©s chargÃ©s depuis c:\PI4\6\residence_quebec\data\outputs\calibration\2023\20250403_104404\calibration_results.json
# 2025-04-07 17:26:50703 - src.managers.simulation_manager - INFO - Conversion des paramÃ¨tres plats en format par archÃ©type
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO - Chargement automatique des paramÃ¨tres calibrÃ©s pour l'annÃ©e de rÃ©fÃ©rence 2023
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO - ParamÃ¨tres de calibration adaptÃ©s pour 2050_cold_UB_E (Ã©chantillon):
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ window_ufactor: {0: -0.23114708777645132, 1: -0.23114708777645132, 2: -0.23114708777645132}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ infiltration_rate: {0: 0.323395337799037, 1: 0.323395337799037, 2: 0.323395337799037}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ wall_rvalue: {0: -0.26579423834572924, 1: -0.26579423834572924, 2: -0.26579423834572924}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ ceiling_rvalue: {0: 0.03346512782241194, 1: 0.03346512782241194, 2: 0.03346512782241194}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ heating_setpoint: {0: 0.12288720783283547, 1: 0.12288720783283547, 2: 0.12288720783283547}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ heating_efficiency: {0: -0.08424796752290242, 1: -0.08424796752290242, 2: -0.08424796752290242}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ cooling_setpoint: {0: -0.011993613657457616, 1: -0.011993613657457616, 2: -0.011993613657457616}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ occupancy_scale: {0: 0.2608769076607903, 1: 0.2608769076607903, 2: 0.2608769076607903}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ lighting_scale: {0: -0.1019776968323251, 1: -0.1019776968323251, 2: -0.1019776968323251}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ appliance_scale: {0: -0.23142542823277812, 1: -0.23142542823277812, 2: -0.23142542823277812}
# 2025-04-07 17:26:50704 - src.managers.simulation_manager - INFO -   â†’ temporal_diversity: {0: 0.9487296024220949, 1: 0.9487296024220949, 2: 0.9487296024220949}
# 2025-04-07 17:26:50704 - src.scenario_manager - INFO - Application des amÃ©liorations d'enveloppe et d'efficacitÃ© Ã  tous les archÃ©types
# 2025-04-07 17:26:51619 - src.scenario_manager - INFO - ScÃ©nario Ultra Bas carbone (UB): Ã©lectrification plus agressive (120.0%)
# 2025-04-07 17:26:51619 - src.scenario_manager - INFO - Transformation de 15/13 archÃ©types avec systÃ¨mes fossiles
# 2025-04-07 17:26:51622 - src.scenario_manager - INFO - Statistiques de transformation: {'total_fossil': 13, 'transformed': 15, 'to_heat_pump': 12, 'to_electric': 1, 'unchanged': -2}
# 2025-04-07 17:26:51626 - src.scenario_manager - INFO - Nouveau mix de chauffage des archÃ©types: {'heat_pump': 0.3484848484848485, 'Electric': 0.5606060606060606, 'Mixed Wood': 0.09090909090909091}
# 2025-04-07 17:26:51639 - src.managers.simulation_manager - INFO - VÃ©rification des transformations pour 2050_cold_UB_E:
# 2025-04-07 17:26:51639 - src.managers.simulation_manager - INFO -   â†’ 66/66 archÃ©types modifiÃ©s (100.0%)
# 2025-04-07 17:26:51643 - src.schedule_generator - INFO - Archetype 0: DÃ©calages temporels - matin: 1.63h, midi: -0.23h, soir: 1.22h, nuit: -0.46h
# 2025-04-07 17:26:51889 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:26:51890 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:26:51890 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2050_cold_1.0 pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:51891 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2050_cold_1.0
# 2025-04-07 17:26:51891 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/cold/Weatherfile_Tas min year_GW1.0_7016293.epw pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:51895 - src.schedule_generator - INFO - Archetype 1: DÃ©calages temporels - matin: -1.98h, midi: -0.20h, soir: -0.39h, nuit: -0.65h
# 2025-04-07 17:26:52128 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:26:52130 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:26:52130 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2050_cold_1.0 pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52131 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2050_cold_1.0
# 2025-04-07 17:26:52131 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/cold/Weatherfile_Tas min year_GW1.0_7016293.epw pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52137 - src.schedule_generator - INFO - Archetype 2: DÃ©calages temporels - matin: -1.22h, midi: -1.38h, soir: 1.68h, nuit: -0.61h
# 2025-04-07 17:26:52380 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:26:52382 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:26:52382 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2050_cold_1.0 pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52382 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2050_cold_1.0
# 2025-04-07 17:26:52382 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/cold/Weatherfile_Tas min year_GW1.0_7016293.epw pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52385 - src.schedule_generator - INFO - Archetype 3: DÃ©calages temporels - matin: -0.75h, midi: 1.02h, soir: 1.73h, nuit: 0.80h
# 2025-04-07 17:26:52630 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:26:52632 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:26:52632 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2050_cold_1.0 pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52633 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2050_cold_1.0
# 2025-04-07 17:26:52633 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/cold/Weatherfile_Tas min year_GW1.0_7016293.epw pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52636 - src.schedule_generator - INFO - Archetype 4: DÃ©calages temporels - matin: -0.29h, midi: -1.36h, soir: 1.25h, nuit: -0.83h
# 2025-04-07 17:26:52895 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:26:52897 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:26:52897 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2050_cold_1.0 pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52898 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2050_cold_1.0
# 2025-04-07 17:26:52898 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/cold/Weatherfile_Tas min year_GW1.0_7016293.epw pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:52901 - src.schedule_generator - INFO - Archetype 5: DÃ©calages temporels - matin: 0.08h, midi: -0.10h, soir: -0.87h, nuit: -0.23h
# 2025-04-07 17:26:53146 - src.managers.archetype_manager - WARNING - Correction auto thermopompe: COP â†’ HSPF (0.3921717665938436 â†’ 1.3373057240850068)
# 2025-04-07 17:26:53146 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:26:53149 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:26:53149 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2050_cold_1.0 pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26:53149 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2050_cold_1.0
# 2025-04-07 17:26:53151 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/cold/Weatherfile_Tas min year_GW1.0_7016293.epw pour le scÃ©nario 2050_cold_UB_E
# 2025-04-07 17:26
- root - INFO - Successfully saved results to c:\PI4\6\residence_quebec\data\outputs\simulations\2050\2050_cold_UB_E\mrc\mrc_2477\hourly.csv
# 2025-04-07 17:31:26732 - root - INFO - Successfully saved results to c:\PI4\6\residence_quebec\data\outputs\simulations\2050\2050_cold_UB_E\mrc\mrc_2478\hourly.csv
# 2025-04-07 17:31:27046 - root - INFO - Simulation and aggregation completed for future scenario 2050_cold_UB_E. Results saved in data/outputs/simulations/2050/2050_cold_UB_E/
# Simulation Réussie pour 2050_cold_UB_E en 279.9 secondes

# %% [markdown]
# ## 2. Simulation de tous les scénarios
#
# Cette section permet de simuler tous les scénarios futurs en séquence.

# %%
# Définir les scénarios à exécuter (tous par défaut)
# Vous pouvez filtrer cette liste pour ne sélectionner que certains scénarios
scenarios_to_run = config.future_scenarios.SCENARIOS.copy()

# Exemple de filtre pour simuler uniquement les scénarios 2035
# scenarios_to_run = [s for s in scenarios_to_run if s.startswith('2035')]

print(f"Scénarios à simuler ({len(scenarios_to_run)}):\n- " + "\n- ".join(scenarios_to_run))
# Out:
# Scénarios à simuler (24):
# - 2035_warm_PV_E
# - 2035_warm_PV_EE
# - 2035_warm_UB_E
# - 2035_warm_UB_EE
# - 2035_typical_PV_E
# - 2035_typical_PV_EE
# - 2035_typical_UB_E
# - 2035_typical_UB_EE
# - 2035_cold_PV_E
# - 2035_cold_PV_EE
# - 2035_cold_UB_E
# - 2035_cold_UB_EE
# - 2050_warm_PV_E
# - 2050_warm_PV_EE
# - 2050_warm_UB_E
# - 2050_warm_UB_EE
# - 2050_typical_PV_E
# - 2050_typical_PV_EE
# - 2050_typical_UB_E
# - 2050_typical_UB_EE
# - 2050_cold_PV_E
# - 2050_cold_PV_EE
# - 2050_cold_UB_E
# - 2050_cold_UB_EE

# %%
# Exécuter tous les scénarios sélectionnés
# Note: Cela peut prendre beaucoup de temps!
# Mettre verbose=False pour n'afficher que les résumés
all_results = run_multiple_simulations(scenarios_to_run, verbose=True)
# Out:
# [1/24] Simulation du scénario 2035_warm_PV_E
# Démarrage de la simulation pour 2035_warm_PV_E...
# 2025-04-07 17:31:30,204 - src.calibration.transfer_learning_manager - INFO - Base de connaissances chargÃ©e avec 3 entrÃ©es
# 2025-04-07 17:31:30,204 - src.calibration.transfer_learning_manager - INFO - Chargement du modÃ¨le de transfert existant
# 2025-04-07 17:31:30,209 - src.calibration.transfer_learning_manager - INFO - ModÃ¨le de transfert chargÃ© avec succÃ¨s
# 2025-04-07 17:31:30236 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:30237 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:30237 - src.managers.simulation_manager - INFO - Tentative de chargement des paramÃ¨tres de calibration pour l'annÃ©e 2023
# 2025-04-07 17:31:30237 - src.managers.simulation_manager - INFO - RÃ©pertoire de calibration: c:\PI4\6\residence_quebec\data\outputs\calibration\2023
# 2025-04-07 17:31:30598 - src.managers.simulation_manager - INFO - Fichier de rÃ©sultats de calibration le plus rÃ©cent: c:\PI4\6\residence_quebec\data\outputs\calibration\2023\20250403_104404\calibration_results.json
# 2025-04-07 17:31:30598 - src.managers.simulation_manager - INFO - ParamÃ¨tres calibrÃ©s chargÃ©s depuis c:\PI4\6\residence_quebec\data\outputs\calibration\2023\20250403_104404\calibration_results.json
# 2025-04-07 17:31:30598 - src.managers.simulation_manager - INFO - Conversion des paramÃ¨tres plats en format par archÃ©type
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO - Chargement automatique des paramÃ¨tres calibrÃ©s pour l'annÃ©e de rÃ©fÃ©rence 2023
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO - ParamÃ¨tres de calibration adaptÃ©s pour 2035_warm_PV_E (Ã©chantillon):
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ window_ufactor: {0: -0.23114708777645132, 1: -0.23114708777645132, 2: -0.23114708777645132}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ infiltration_rate: {0: 0.30637453054645614, 1: 0.30637453054645614, 2: 0.30637453054645614}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ wall_rvalue: {0: -0.27845110683838303, 1: -0.27845110683838303, 2: -0.27845110683838303}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ ceiling_rvalue: {0: 0.035058705337764895, 1: 0.035058705337764895, 2: 0.035058705337764895}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ heating_setpoint: {0: 0.12288720783283547, 1: 0.12288720783283547, 2: 0.12288720783283547}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ heating_efficiency: {0: -0.08424796752290242, 1: -0.08424796752290242, 2: -0.08424796752290242}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ cooling_setpoint: {0: -0.011993613657457616, 1: -0.011993613657457616, 2: -0.011993613657457616}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ occupancy_scale: {0: 0.2608769076607903, 1: 0.2608769076607903, 2: 0.2608769076607903}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ lighting_scale: {0: -0.1019776968323251, 1: -0.1019776968323251, 2: -0.1019776968323251}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ appliance_scale: {0: -0.23142542823277812, 1: -0.23142542823277812, 2: -0.23142542823277812}
# 2025-04-07 17:31:30600 - src.managers.simulation_manager - INFO -   â†’ temporal_diversity: {0: 0.9487296024220949, 1: 0.9487296024220949, 2: 0.9487296024220949}
# 2025-04-07 17:31:30600 - src.scenario_manager - INFO - Application des amÃ©liorations d'enveloppe et d'efficacitÃ© Ã  tous les archÃ©types
# 2025-04-07 17:31:31483 - src.scenario_manager - INFO - Transformation de 10/13 archÃ©types avec systÃ¨mes fossiles
# 2025-04-07 17:31:31485 - src.scenario_manager - INFO - Statistiques de transformation: {'total_fossil': 13, 'transformed': 10, 'to_heat_pump': 4, 'to_electric': 6, 'unchanged': 3}
# 2025-04-07 17:31:31489 - src.scenario_manager - INFO - Nouveau mix de chauffage des archÃ©types: {'heat_pump': 0.25757575757575757, 'Electric': 0.6212121212121212, 'Mixed Wood': 0.09090909090909091, 'Natural gas': 0.015151515151515152, 'Oil': 0.015151515151515152}
- src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:43636 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:43636 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:43636 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2035_warm_1.5
# 2025-04-07 17:31:43636 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/warm/Weatherfile_Tas max year_GW1.5_7033121.epw pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:43649 - src.schedule_generator - INFO - Archetype 49: DÃ©calages temporels - matin: 2.06h, midi: 0.81h, soir: -2.37h, nuit: -0.26h
# 2025-04-07 17:31:43895 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:43896 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:43896 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:43896 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2035_warm_1.5
# 2025-04-07 17:31:43896 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/warm/Weatherfile_Tas max year_GW1.5_7033121.epw pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:43901 - src.schedule_generator - INFO - Archetype 50: DÃ©calages temporels - matin: -1.21h, midi: -1.25h, soir: 1.52h, nuit: 0.61h
# 2025-04-07 17:31:44142 - src.managers.archetype_manager - WARNING - Correction auto thermopompe: COP â†’ HSPF (0.6457565712303148 â†’ 2.2020299078953736)
# 2025-04-07 17:31:44142 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:44145 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:44145 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44145 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2035_warm_1.5
# 2025-04-07 17:31:44145 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/warm/Weatherfile_Tas max year_GW1.5_7034900.epw pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44149 - src.schedule_generator - INFO - Archetype 51: DÃ©calages temporels - matin: 2.21h, midi: 1.08h, soir: -0.23h, nuit: -0.26h
# 2025-04-07 17:31:44384 - src.managers.archetype_manager - WARNING - Correction auto thermopompe: COP â†’ HSPF (0.6462866373035415 â†’ 2.2038374332050767)
# 2025-04-07 17:31:44384 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:44386 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:44386 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44387 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2035_warm_1.5
# 2025-04-07 17:31:44387 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/warm/Weatherfile_Tas max year_GW1.5_7034900.epw pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44395 - src.schedule_generator - INFO - Archetype 52: DÃ©calages temporels - matin: -1.93h, midi: 0.80h, soir: 1.19h, nuit: -0.65h
# 2025-04-07 17:31:44632 - src.managers.archetype_manager - WARNING - Correction auto thermopompe: COP â†’ HSPF (0.33200208537901005 â†’ 1.1321271111424243)
# 2025-04-07 17:31:44632 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:44632 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:44632 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44632 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2035_warm_1.5
# 2025-04-07 17:31:44632 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/warm/Weatherfile_Tas max year_GW1.5_7034900.epw pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44642 - src.schedule_generator - INFO - Archetype 53: DÃ©calages temporels - matin: 1.39h, midi: -0.82h, soir: -0.76h, nuit: 0.19h
# 2025-04-07 17:31:44876 - src.managers.archetype_manager - WARNING - Correction auto thermopompe: COP â†’ HSPF (0.3633501651582687 â†’ 1.2390240631896963)
# 2025-04-07 17:31:44876 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:44879 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:44879 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44880 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2035_warm_1.5
# 2025-04-07 17:31:44880 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/warm/Weatherfile_Tas max year_GW1.5_7034900.epw pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:44889 - src.schedule_generator - INFO - Archetype 54: DÃ©calages temporels - matin: -0.26h, midi: 1.22h, soir: 1.64h, nuit: 0.09h
# 2025-04-07 17:31:45108 - src.managers.archetype_manager - WARNING - Correction auto thermopompe: COP â†’ HSPF (0.8509870317524436 â†’ 2.901865778275833)
# 2025-04-07 17:31:45108 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:45110 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:45110 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:45110 - src.scenario_manager - INFO - Colonne cible trouvÃ©e: EPW_2035_warm_1.5
# 2025-04-07 17:31:45112 - src.scenario_manager - INFO - Utilisation du fichier mÃ©tÃ©o: future/warm/Weatherfile_Tas max year_GW1.5_7034900.epw pour le scÃ©nario 2035_warm_PV_E
# 2025-04-07 17:31:45116 - src.schedule_generator - INFO - Archetype 55: DÃ©calages temporels - matin: 0.75h, midi: -0.15h, soir: -1.60h, nuit: -0.44h
# 2025-04-07 17:31:45359 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 17:31:45362 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 17:31:45362 - src.scenario_manager - INFO - Recherche de la colonne spÃ©cifique: EPW_2035_warm_1.5 pour le scÃ©nario 2035_warm_PV_E
# ...
# 2025-04-07 18:16:56862 - src.managers.simulation_manager - INFO - Archetype 15 simulÃ© avec succÃ¨s [1/66]
# 2025-04-07 18:16:57,769 - src.managers.simulation_manager - INFO - Simulation completed: archetype_3
# 2025-04-07 18:16:57942 - src.managers.simulation_manager - INFO - Archetype 3 simulÃ© avec succÃ¨s [2/66]
# 2025-04-07 18:16:58,270 - src.managers.simulation_manager - INFO - Simulation completed: archetype_13
# 2025-04-07 18:16:58373 - src.managers.simulation_manager - INFO - Archetype 13 simulÃ© avec succÃ¨s [3/66]
# 2025-04-07 18:16:58,465 - src.managers.simulation_manager - INFO - Simulation completed: archetype_7
# 2025-04-07 18:16:58627 - src.managers.simulation_manager - INFO - Archetype 7 simulÃ© avec succÃ¨s [4/66]
# 2025-04-07 18:16:58,692 - src.managers.simulation_manager - INFO - Simulation completed: archetype_1
# 2025-04-07 18:16:58982 - src.managers.simulation_manager - INFO - Archetype 1 simulÃ© avec succÃ¨s [5/66]
# 2025-04-07 18:17:01,733 - src.managers.simulation_manager - INFO - Simulation completed: archetype_11
# 2025-04-07 18:17:01901 - src.managers.simulation_manager - INFO - Archetype 11 simulÃ© avec succÃ¨s [6/66]
# 2025-04-07 18:17:06,092 - src.managers.simulation_manager - INFO - Simulation completed: archetype_9
# 2025-04-07 18:17:06,151 - src.managers.simulation_manager - INFO - Simulation completed: archetype_5
# 2025-04-07 18:17:06521 - src.managers.simulation_manager - INFO - Archetype 9 simulÃ© avec succÃ¨s [7/66]
# 2025-04-07 18:17:07660 - src.managers.simulation_manager - INFO - Archetype 5 simulÃ© avec succÃ¨s [8/66]
# 2025-04-07 18:17:07,833 - src.managers.simulation_manager - INFO - Simulation completed: archetype_19
# 2025-04-07 18:17:09443 - src.managers.simulation_manager - INFO - Archetype 19 simulÃ© avec succÃ¨s [9/66]
# 2025-04-07 18:17:09,502 - src.managers.simulation_manager - INFO - Simulation completed: archetype_6
# 2025-04-07 18:17:09602 - src.managers.simulation_manager - INFO - Archetype 6 simulÃ© avec succÃ¨s [10/66]
# 2025-04-07 18:17:10,378 - src.managers.simulation_manager - INFO - Simulation completed: archetype_8
# 2025-04-07 18:17:10519 - src.managers.simulation_manager - INFO - Archetype 8 simulÃ© avec succÃ¨s [11/66]
# 2025-04-07 18:17:10,710 - src.managers.simulation_manager - INFO - Simulation completed: archetype_21
# 2025-04-07 18:17:10886 - src.managers.simulation_manager - INFO - Archetype 21 simulÃ© avec succÃ¨s [12/66]
# 2025-04-07 18:17:10,962 - src.managers.simulation_manager - INFO - Simulation completed: archetype_2
# 2025-04-07 18:17:11101 - src.managers.simulation_manager - INFO - Archetype 2 simulÃ© avec succÃ¨s [13/66]
# 2025-04-07 18:17:11,298 - src.managers.simulation_manager - INFO - Simulation completed: archetype_14
# 2025-04-07 18:17:11468 - src.managers.simulation_manager - INFO - Archetype 14 simulÃ© avec succÃ¨s [14/66]
# 2025-04-07 18:17:11,770 - src.managers.simulation_manager - INFO - Simulation completed: archetype_16
# 2025-04-07 18:17:11869 - src.managers.simulation_manager - INFO - Archetype 16 simulÃ© avec succÃ¨s [15/66]
# 2025-04-07 18:17:12,449 - src.managers.simulation_manager - INFO - Simulation completed: archetype_22
# 2025-04-07 18:17:12541 - src.managers.simulation_manager - INFO - Archetype 22 simulÃ© avec succÃ¨s [16/66]
# 2025-04-07 18:17:13,365 - src.managers.simulation_manager - INFO - Simulation completed: archetype_0
# 2025-04-07 18:17:13539 - src.managers.simulation_manager - INFO - Archetype 0 simulÃ© avec succÃ¨s [17/66]
# 2025-04-07 18:17:13,887 - src.managers.simulation_manager - INFO - Simulation completed: archetype_17
# 2025-04-07 18:17:13973 - src.managers.simulation_manager - INFO - Archetype 17 simulÃ© avec succÃ¨s [18/66]
# 2025-04-07 18:17:14,176 - src.managers.simulation_manager - INFO - Simulation completed: archetype_12
# 2025-04-07 18:17:14239 - src.managers.simulation_manager - INFO - Archetype 12 simulÃ© avec succÃ¨s [19/66]
# 2025-04-07 18:17:14,262 - src.managers.simulation_manager - INFO - Simulation completed: archetype_4
# 2025-04-07 18:17:14,262 - src.managers.simulation_manager - INFO - Simulation completed: archetype_10
# 2025-04-07 18:17:14392 - src.managers.simulation_manager - INFO - Archetype 4 simulÃ© avec succÃ¨s [20/66]
# 2025-04-07 18:17:14464 - src.managers.simulation_manager - INFO - Archetype 10 simulÃ© avec succÃ¨s [21/66]
# 2025-04-07 18:17:16,474 - src.managers.simulation_manager - INFO - Simulation completed: archetype_23
# 2025-04-07 18:17:16556 - src.managers.simulation_manager - INFO - Archetype 23 simulÃ© avec succÃ¨s [22/66]
# 2025-04-07 18:17:19,771 - src.managers.simulation_manager - INFO - Simulation completed: archetype_18
# 2025-04-07 18:17:19852 - src.managers.simulation_manager - INFO - Archetype 18 simulÃ© avec succÃ¨s [23/66]
# 2025-04-07 18:17:19,934 - src.managers.simulation_manager - INFO - Simulation completed: archetype_20
# 2025-04-07 18:17:20104 - src.managers.simulation_manager - INFO - Archetype 20 simulÃ© avec succÃ¨s [24/66]
# 2025-04-07 18:17:20,840 - src.managers.simulation_manager - INFO - Simulation completed: archetype_26
# 2025-04-07 18:17:21192 - src.managers.simulation_manager - INFO - Archetype 26 simulÃ© avec succÃ¨s [25/66]
# 2025-04-07 18:17:22,013 - src.managers.simulation_manager - INFO - Simulation completed: archetype_28
# 2025-04-07 18:17:22189 - src.managers.simulation_manager - INFO - Archetype 28 simulÃ© avec succÃ¨s [26/66]
# 2025-04-07 18:17:22,415 - src.managers.simulation_manager - INFO - Simulation completed: archetype_24
# 2025-04-07 18:17:22491 - src.managers.simulation_manager - INFO - Archetype 24 simulÃ© avec succÃ¨s [27/66]
# 2025-04-07 18:17:25,069 - src.managers.simulation_manager - INFO - Simulation completed: archetype_25
# 2025-04-07 18:17:25258 - src.managers.simulation_manager - INFO - Archetype 25 simulÃ© avec succÃ¨s [28/66]
# 2025-04-07 18:17:29,005 - src.managers.simulation_manager - INFO - Simulation completed: archetype_33
# 2025-04-07 18:17:29,035 - src.managers.simulation_manager - INFO - Simulation completed: archetype_30
# 2025-04-07 18:17:29225 - src.managers.simulation_manager - INFO - Archetype 33 simulÃ© avec succÃ¨s [29/66]
# 2025-04-07 18:17:29566 - src.managers.simulation_manager - INFO - Archetype 30 simulÃ© avec succÃ¨s [30/66]
# 2025-04-07 18:17:31,332 - src.managers.simulation_manager - INFO - Simulation completed: archetype_35
# 2025-04-07 18:17:31499 - src.managers.simulation_manager - INFO - Archetype 35 simulÃ© avec succÃ¨s [31/66]
# 2025-04-07 18:17:31,516 - src.managers.simulation_manager - INFO - Simulation completed: archetype_41
# 2025-04-07 18:17:31616 - src.managers.simulation_manager - INFO - Archetype 41 simulÃ© avec succÃ¨s [32/66]
# 2025-04-07 18:17:32,383 - src.managers.simulation_manager - INFO - Simulation completed: archetype_43
# 2025-04-07 18:17:32466 - src.managers.simulation_manager - INFO - Archetype 43 simulÃ© avec succÃ¨s [33/66]
# 2025-04-07 18:17:32,666 - src.managers.simulation_manager - INFO - Simulation completed: archetype_37
# 2025-04-07 18:17:32799 - src.managers.simulation_manager - INFO - Archetype 37 simulÃ© avec succÃ¨s [34/66]
# 2025-04-07 18:17:35,316 - src.managers.simulation_manager - INFO - Simulation completed: archetype_39
# 2025-04-07 18:17:35432 - src.managers.simulation_manager - INFO - Archetype 39 simulÃ© avec succÃ¨s [35/66]
# 2025-04-07 18:17:37,758 - src.managers.simulation_manager - INFO - Simulation completed: archetype_27
# 2025-04-07 18:17:38132 - src.managers.simulation_manager - INFO - Archetype 27 simulÃ© avec succÃ¨s [36/66]
# 2025-04-07 18:17:38,266 - src.managers.simulation_manager - INFO - Simulation completed: archetype_32
# 2025-04-07 18:17:38515 - src.managers.simulation_manager - INFO - Archetype 32 simulÃ© avec succÃ¨s [37/66]
# 2025-04-07 18:17:38,750 - src.managers.simulation_manager - INFO - Simulation completed: archetype_31
# 2025-04-07 18:17:39,115 - src.managers.simulation_manager - INFO - Simulation completed: archetype_38
# 2025-04-07 18:17:39275 - src.managers.simulation_manager - INFO - Archetype 31 simulÃ© avec succÃ¨s [38/66]
# 2025-04-07 18:17:39475 - src.managers.simulation_manager - INFO - Archetype 38 simulÃ© avec succÃ¨s [39/66]
# 2025-04-07 18:17:40,097 - src.managers.simulation_manager - INFO - Simulation completed: archetype_29
# 2025-04-07 18:17:40,115 - src.managers.simulation_manager - INFO - Simulation completed: archetype_46
# 2025-04-07 18:17:40165 - src.managers.simulation_manager - INFO - Archetype 29 simulÃ© avec succÃ¨s [40/66]
# 2025-04-07 18:17:40546 - src.managers.simulation_manager - INFO - Archetype 46 simulÃ© avec succÃ¨s [41/66]
# 2025-04-07 18:17:41,056 - src.managers.simulation_manager - INFO - Simulation completed: archetype_36
# 2025-04-07 18:17:41,211 - src.managers.simulation_manager - INFO - Simulation completed: archetype_40
# 2025-04-07 18:17:41374 - src.managers.simulation_manager - INFO - Archetype 36 simulÃ© avec succÃ¨s [42/66]
# 2025-04-07 18:17:42001 - src.managers.simulation_manager - INFO - Archetype 40 simulÃ© avec succÃ¨s [43/66]
# 2025-04-07 18:17:42,005 - src.managers.simulation_manager - INFO - Simulation completed: archetype_34
# 2025-04-07 18:17:42164 - src.managers.simulation_manager - INFO - Archetype 34 simulÃ© avec succÃ¨s [44/66]
# 2025-04-07 18:17:42,299 - src.managers.simulation_manager - INFO - Simulation completed: archetype_48
# 2025-04-07 18:17:42371 - src.managers.simulation_manager - INFO - Archetype 48 simulÃ© avec succÃ¨s [45/66]
# 2025-04-07 18:17:43,542 - src.managers.simulation_manager - INFO - Simulation completed: archetype_50
# 2025-04-07 18:17:44511 - src.managers.simulation_manager - INFO - Archetype 50 simulÃ© avec succÃ¨s [46/66]
# 2025-04-07 18:17:47,769 - src.managers.simulation_manager - INFO - Simulation completed: archetype_42
# 2025-04-07 18:17:47871 - src.managers.simulation_manager - INFO - Archetype 42 simulÃ© avec succÃ¨s [47/66]
# 2025-04-07 18:17:48,655 - src.managers.simulation_manager - INFO - Simulation completed: archetype_52
# 2025-04-07 18:17:48735 - src.managers.simulation_manager - INFO - Archetype 52 simulÃ© avec succÃ¨s [48/66]
# 2025-04-07 18:17:50,083 - src.managers.simulation_manager - INFO - Simulation completed: archetype_44
# 2025-04-07 18:17:50192 - src.managers.simulation_manager - INFO - Archetype 44 simulÃ© avec succÃ¨s [49/66]
# 2025-04-07 18:17:51,539 - src.managers.simulation_manager - INFO - Simulation completed: archetype_57
# 2025-04-07 18:17:51820 - src.managers.simulation_manager - INFO - Archetype 57 simulÃ© avec succÃ¨s [50/66]
# 2025-04-07 18:17:52,085 - src.managers.simulation_manager - INFO - Simulation completed: archetype_60
# 2025-04-07 18:17:52287 - src.managers.simulation_manager - INFO - Archetype 60 simulÃ© avec succÃ¨s [51/66]
# 2025-04-07 18:17:53,367 - src.managers.simulation_manager - INFO - Simulation completed: archetype_45
# 2025-04-07 18:17:53591 - src.managers.simulation_manager - INFO - Archetype 45 simulÃ© avec succÃ¨s [52/66]
# 2025-04-07 18:17:53,684 - src.managers.simulation_manager - INFO - Simulation completed: archetype_49
# 2025-04-07 18:17:53737 - src.managers.simulation_manager - INFO - Archetype 49 simulÃ© avec succÃ¨s [53/66]
# 2025-04-07 18:17:54,045 - src.managers.simulation_manager - INFO - Simulation completed: archetype_47
# 2025-04-07 18:17:54342 - src.managers.simulation_manager - INFO - Archetype 47 simulÃ© avec succÃ¨s [54/66]
# 2025-04-07 18:17:54,824 - src.managers.simulation_manager - INFO - Simulation completed: archetype_54
# 2025-04-07 18:17:54889 - src.managers.simulation_manager - INFO - Archetype 54 simulÃ© avec succÃ¨s [55/66]
# 2025-04-07 18:17:55,133 - src.managers.simulation_manager - INFO - Simulation completed: archetype_59
# 2025-04-07 18:17:55320 - src.managers.simulation_manager - INFO - Archetype 59 simulÃ© avec succÃ¨s [56/66]
# 2025-04-07 18:17:58,323 - src.managers.simulation_manager - INFO - Simulation completed: archetype_51
# 2025-04-07 18:17:58481 - src.managers.simulation_manager - INFO - Archetype 51 simulÃ© avec succÃ¨s [57/66]
# 2025-04-07 18:17:58,717 - src.managers.simulation_manager - INFO - Simulation completed: archetype_62
# 2025-04-07 18:17:58782 - src.managers.simulation_manager - INFO - Archetype 62 simulÃ© avec succÃ¨s [58/66]
# 2025-04-07 18:18:00,523 - src.managers.simulation_manager - INFO - Simulation completed: archetype_65
# 2025-04-07 18:18:00737 - src.managers.simulation_manager - INFO - Archetype 65 simulÃ© avec succÃ¨s [59/66]
# 2025-04-07 18:18:00,886 - src.managers.simulation_manager - INFO - Simulation completed: archetype_53
# 2025-04-07 18:18:00943 - src.managers.simulation_manager - INFO - Archetype 53 simulÃ© avec succÃ¨s [60/66]
# 2025-04-07 18:18:01,484 - src.managers.simulation_manager - INFO - Simulation completed: archetype_55
# 2025-04-07 18:18:01543 - src.managers.simulation_manager - INFO - Archetype 55 simulÃ© avec succÃ¨s [61/66]
# 2025-04-07 18:18:01,617 - src.managers.simulation_manager - INFO - Simulation completed: archetype_56
# 2025-04-07 18:18:01733 - src.managers.simulation_manager - INFO - Archetype 56 simulÃ© avec succÃ¨s [62/66]
# 2025-04-07 18:18:02,731 - src.managers.simulation_manager - INFO - Simulation completed: archetype_58
# 2025-04-07 18:18:02792 - src.managers.simulation_manager - INFO - Archetype 58 simulÃ© avec succÃ¨s [63/66]
# 2025-04-07 18:18:02,957 - src.managers.simulation_manager - INFO - Simulation completed: archetype_63
# 2025-04-07 18:18:03015 - src.managers.simulation_manager - INFO - Archetype 63 simulÃ© avec succÃ¨s [64/66]
# 2025-04-07 18:18:03,247 - src.managers.simulation_manager - INFO - Simulation completed: archetype_61
# 2025-04-07 18:18:03295 - src.managers.simulation_manager - INFO - Archetype 61 simulÃ© avec succÃ¨s [65/66]
# 2025-04-07 18:18:03,657 - src.managers.simulation_manager - INFO - Simulation completed: archetype_64
# 2025-04-07 18:18:03704 - src.managers.simulation_manager - INFO - Archetype 64 simulÃ© avec succÃ¨s [66/66]
# 2025-04-07 18:18:08114 - src.scenario_manager - INFO - InitialisÃ© 24 scÃ©narios futurs
# 2025-04-07 18:18:08115 - src.scenario_manager - INFO - Mapping mÃ©tÃ©o futur chargÃ©: 5 zones
# 2025-04-07 18:18:24289 - src.scenario_manager - INFO - ParamÃ¨tres de croissance pour 2035_cold_UB_EE:
# 2025-04-07 18:18:24289 - src.scenario_manager - INFO -   â†’ Croissance totale: 0.12
# 2025-04-07 18:18:24289 - src.scenario_manager - INFO -   â†’ Croissance appartements: 0.05
# 2025-04-07 18:18:24289 - src.scenario_manager - INFO -   â†’ RÃ©duction/croissance maisons: -0.05
# 2025-04-07 18:18:24289 - src.scenario_manager - INFO - ScÃ©nario Ultra Bas carbone (UB): Ajustement de la transformation des maisons unifamiliales (-0.06)
# 2025-04-07 18:18:24630 - src.scenario_manager - INFO - CROISSANCE MAISONS: Surface Ã  ajouter: 15107636.2 mÂ² (facteur 0.06)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 # Exécuter tous les scénarios sélectionnés
#       2 # Note: Cela peut prendre beaucoup de temps!
#       3 # Mettre verbose=False pour n'afficher que les résumés
# ----> 4 all_results = run_multiple_simulations(scenarios_to_run, verbose=True)
#
# Cell In[4], line 17, in run_multiple_simulations(scenarios, verbose)
#      15 for i, scenario in enumerate(scenarios, 1):
#      16     print(f"\n[{i}/{len(scenarios)}] Simulation du scénario {scenario}")
# ---> 17     success, output = run_simulation(scenario, verbose=verbose)
#      18     results[scenario] = (success, output)
#      20     # Afficher un résumé après chaque simulation
#
# Cell In[3], line 33, in run_simulation(scenario_key, verbose)
#      31 # Capture de la sortie
#      32 output_lines = []
# ---> 33 for line in process.stdout:
#      34     output_lines.append(line.rstrip())
#      35     if verbose:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\encodings\cp1252.py:22, in IncrementalDecoder.decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
# ---> 22     def decode(self, input, final=False):
#      23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Analyse des résultats
#
# Cette section permet d'explorer et visualiser les résultats des simulations.

# %%
# Fonction pour charger les résultats d'un scénario
def load_scenario_results(scenario_key):
    """Charge les résultats d'un scénario.
    
    Args:
        scenario_key: Clé du scénario (ex: '2035_warm_PV_E')
        
    Returns:
        Tuple (provincial_results, provincial_summary, zones)
    """
    # Extraire l'année du scénario
    year = config.future_scenarios.get_scenario_year(scenario_key)
    
    # Construire les chemins
    base_dir = config.paths['output'].get_simulation_dir(year, scenario_key)
    provincial_dir = base_dir / 'provincial'
    zones_dir = base_dir / 'zones'
    
    # Vérifier que les fichiers existent
    if not provincial_dir.exists() or not (provincial_dir / 'hourly.csv').exists():
        print(f"Erreur: Résultats provinciaux non trouvés pour {scenario_key}")
        return None, None, {}
    
    # Charger les résultats provinciaux
    provincial_results = pd.read_csv(provincial_dir / 'hourly.csv')
    provincial_results['Time'] = pd.to_datetime(provincial_results['Time'])
    provincial_results.set_index('Time', inplace=True)
    
    # Charger le résumé provincial
    with open(provincial_dir / 'summary.json', 'r') as f:
        provincial_summary = json.load(f)
    
    # Charger les résultats des zones
    zones = {}
    if zones_dir.exists():
        for zone_dir in zones_dir.glob('zone_*'):
            zone_id = int(zone_dir.name.replace('zone_', ''))
            if (zone_dir / 'hourly.csv').exists():
                zone_results = pd.read_csv(zone_dir / 'hourly.csv')
                zone_results['Time'] = pd.to_datetime(zone_results['Time'])
                zone_results.set_index('Time', inplace=True)
                
                # Charger le résumé de la zone
                try:
                    with open(zone_dir / 'summary.json', 'r') as f:
                        zone_summary = json.load(f)
                except:
                    zone_summary = {}
                    
                zones[zone_id] = {
                    'results': zone_results,
                    'summary': zone_summary
                }
    
    return provincial_results, provincial_summary, zones

# %%
# Sélectionner un scénario pour l'analyse
scenario_to_analyze = "2050_warm_UB_E" 

# Charger les résultats
results, summary, zones = load_scenario_results(scenario_to_analyze)

if results is not None:
    # Afficher le résumé
    print(f"Résumé du scénario {scenario_to_analyze}:")
    annual_consumption = summary.get('annual_consumption', {})
    total_kwh = annual_consumption.get('total_kwh', 0)
    total_gwh = annual_consumption.get('total_gwh', 0)
    print(f"- Consommation totale: {total_gwh:.1f} GWh ({total_kwh:.0f} kWh)")
    
    # Afficher les usages finaux
    print("\nRépartition par usage final:")
    end_uses = {k: v for k, v in annual_consumption.items() if '_kwh' in k and k != 'total_kwh'}
    for use, kwh in end_uses.items():
        use_name = use.replace('_kwh', '').replace('_', ' ').title()
        percentage = (kwh / total_kwh * 100) if total_kwh > 0 else 0
        print(f"- {use_name}: {kwh/1e6:.1f} GWh ({percentage:.1f}%)")
    
    # Afficher les zones
    print(f"\nZones: {len(zones)}")
    
    # Générer un graphique pour la consommation journalière
    plt.figure(figsize=(12, 6))
    daily = results['Fuel Use: Electricity: Total'].resample('D').sum()
    plt.plot(daily.index, daily.values, label='Consommation journalière')
    plt.title(f"Consommation journalière - {scenario_to_analyze}")
    plt.xlabel("Date")
    plt.ylabel("Électricité (kWh)")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    # Générer un graphique pour les usages finaux mensuels
    end_use_columns = [col for col in results.columns if col.startswith('End Use: Electricity:')]
    if end_use_columns:
        monthly_end_uses = results[end_use_columns].resample('M').sum()
        monthly_end_uses.columns = [col.replace('End Use: Electricity: ', '') for col in monthly_end_uses.columns]
        
        plt.figure(figsize=(14, 7))
        monthly_end_uses.plot(kind='bar', stacked=True, ax=plt.gca())
        plt.title(f"Consommation mensuelle par usage - {scenario_to_analyze}")
        plt.xlabel("Mois")
        plt.ylabel("Électricité (kWh)")
        plt.legend(title="Usages finaux")
        plt.xticks(rotation=45)
        plt.grid(True, alpha=0.3, axis='y')
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## 4. Comparaison entre scénarios
#
# Cette section permet de comparer plusieurs scénarios entre eux.

# %%
# Sélectionner les scénarios à comparer
scenarios_to_compare = [
    "2035_warm_PV_E",
    "2035_warm_PV_EE",
    "2050_warm_PV_E",
    "2050_warm_PV_EE"
]  # À modifier selon les scénarios à comparer

# Charger les résultats de tous les scénarios
scenario_data = {}
for scenario in scenarios_to_compare:
    results, summary, _ = load_scenario_results(scenario)
    if results is not None and summary is not None:
        scenario_data[scenario] = {
            'results': results,
            'summary': summary
        }

if scenario_data:
    # Comparer la consommation totale
    consumption_comparison = [
        {
            'Scénario': scenario,
            'Consommation (GWh)': data['summary'].get('annual_consumption', {}).get('total_gwh', 0),
            'Consommation (TWh)': data['summary'].get('annual_consumption', {}).get('total_gwh', 0) / 1000,
            'Description': config.future_scenarios.SCENARIO_NAMES.get(scenario, scenario)
        }
        for scenario, data in scenario_data.items()
    ]
    
    # Créer un DataFrame pour la comparaison
    comparison_df = pd.DataFrame(consumption_comparison)
    display(comparison_df)
    
    # Visualiser la comparaison
    plt.figure(figsize=(12, 6))
    sns.barplot(x='Scénario', y='Consommation (GWh)', data=comparison_df)
    plt.title("Comparaison de la consommation électrique annuelle")
    plt.ylabel("Consommation (GWh)")
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3, axis='y')
    plt.tight_layout()
    plt.show()
    
    # Comparer les profils mensuels
    plt.figure(figsize=(14, 7))
    for scenario, data in scenario_data.items():
        monthly = data['results']['Fuel Use: Electricity: Total'].resample('M').sum() / 1e6  # Conversion en GWh
        plt.plot(monthly.index, monthly.values, label=scenario)
    
    plt.title("Comparaison des profils mensuels")
    plt.xlabel("Mois")
    plt.ylabel("Consommation (GWh)")
    plt.legend(title="Scénarios")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 5. Impact du changement climatique (2035 vs 2050)
#
# Cette section permet d'analyser l'impact du changement climatique en comparant des scénarios avec les mêmes paramètres mais à différents horizons temporels.

# %%
# Comparer les scénarios 2035 vs 2050 avec mêmes paramètres
climate_comparison_sets = [
    # Format: (scénario 2035, scénario 2050, label)
    ("2035_warm_PV_E", "2050_warm_PV_E", "Warm climate, PV, E"),
    ("2035_cold_PV_E", "2050_cold_PV_E", "Cold climate, PV, E"),
    ("2035_typical_PV_E", "2050_typical_PV_E", "Typical climate, PV, E")
]

for s2035, s2050, label in climate_comparison_sets:
    # Charger les résultats
    data_2035 = load_scenario_results(s2035)
    data_2050 = load_scenario_results(s2050)
    
    if data_2035[0] is not None and data_2050[0] is not None:
        # Comparer la consommation mensuelle
        monthly_2035 = data_2035[0]['Fuel Use: Electricity: Total'].resample('M').sum() / 1e6
        monthly_2050 = data_2050[0]['Fuel Use: Electricity: Total'].resample('M').sum() / 1e6
        
        # Ajuster pour avoir le même index
        monthly_2035.index = [idx.replace(year=2023) for idx in monthly_2035.index]
        monthly_2050.index = [idx.replace(year=2023) for idx in monthly_2050.index]
        
        # Visualiser
        plt.figure(figsize=(14, 7))
        plt.plot(monthly_2035.index, monthly_2035.values, label='2035', color='blue')
        plt.plot(monthly_2050.index, monthly_2050.values, label='2050', color='red')
        plt.title(f"Impact du changement climatique: {label}")
        plt.xlabel("Mois")
        plt.ylabel("Consommation (GWh)")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        
        # Calculer les différences
        diff = monthly_2050 - monthly_2035
        diff_pct = (monthly_2050 - monthly_2035) / monthly_2035 * 100
        
        # Afficher les différences
        plt.figure(figsize=(14, 7))
        plt.bar(diff.index, diff.values, color=['red' if x > 0 else 'blue' for x in diff.values])
        plt.title(f"Différence 2050-2035: {label}")
        plt.xlabel("Mois")
        plt.ylabel("Différence (GWh)")
        plt.grid(True, alpha=0.3, axis='y')
        plt.tight_layout()
        plt.show()
        
        # Afficher un résumé
        total_2035 = data_2035[1]['annual_consumption']['total_gwh']
        total_2050 = data_2050[1]['annual_consumption']['total_gwh']
        diff_total = total_2050 - total_2035
        diff_pct_total = (total_2050 - total_2035) / total_2035 * 100
        
        print(f"\nRésumé pour {label}:")
        print(f"- Total 2035: {total_2035:.1f} GWh")
        print(f"- Total 2050: {total_2050:.1f} GWh")
        print(f"- Différence: {diff_total:.1f} GWh ({diff_pct_total:.1f}%)")

# %% [markdown]
# ## 6. Impact de l'efficacité énergétique (E vs EE)
#
# Cette section permet d'analyser l'impact des mesures d'efficacité énergétique en comparant des scénarios avec efficacité standard (E) et maximale (EE).

# %%
# Comparer les scénarios E vs EE
efficiency_comparison_sets = [
    # Format: (scénario E, scénario EE, label)
    ("2035_warm_PV_E", "2035_warm_PV_EE", "2035, Warm climate, PV"),
    ("2050_warm_PV_E", "2050_warm_PV_EE", "2050, Warm climate, PV"),
    ("2035_typical_UB_E", "2035_typical_UB_EE", "2035, Typical climate, UB")
]

# DataFrame pour stocker les résultats de l'analyse d'efficacité
efficiency_results = []

for s_std, s_eff, label in efficiency_comparison_sets:
    # Charger les résultats
    data_std = load_scenario_results(s_std)
    data_eff = load_scenario_results(s_eff)
    
    if data_std[0] is not None and data_eff[0] is not None:
        # Comparer la consommation mensuelle
        monthly_std = data_std[0]['Fuel Use: Electricity: Total'].resample('M').sum() / 1e6
        monthly_eff = data_eff[0]['Fuel Use: Electricity: Total'].resample('M').sum() / 1e6
        
        # Visualiser
        plt.figure(figsize=(14, 7))
        plt.plot(monthly_std.index, monthly_std.values, label='Efficacité standard (E)', color='orange')
        plt.plot(monthly_eff.index, monthly_eff.values, label='Efficacité maximale (EE)', color='green')
        plt.title(f"Impact de l'efficacité énergétique: {label}")
        plt.xlabel("Mois")
        plt.ylabel("Consommation (GWh)")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        
        # Calculer les économies d'énergie
        savings = monthly_std - monthly_eff
        savings_pct = (monthly_std - monthly_eff) / monthly_std * 100
        
        # Visualiser les économies
        plt.figure(figsize=(14, 7))
        plt.bar(savings.index, savings.values, color='green')
        plt.title(f"Économies d'énergie (E-EE): {label}")
        plt.xlabel("Mois")
        plt.ylabel("Économies (GWh)")
        plt.grid(True, alpha=0.3, axis='y')
        plt.tight_layout()
        plt.show()
        
        # Afficher un résumé
        total_std = data_std[1]['annual_consumption']['total_gwh']
        total_eff = data_eff[1]['annual_consumption']['total_gwh']
        savings_total = total_std - total_eff
        savings_pct_total = (total_std - total_eff) / total_std * 100
        
        print(f"\nRésumé pour {label}:")
        print(f"- Total avec efficacité standard (E): {total_std:.1f} GWh")
        print(f"- Total avec efficacité maximale (EE): {total_eff:.1f} GWh")
        print(f"- Économies: {savings_total:.1f} GWh ({savings_pct_total:.1f}%)")
        
        # Ajouter au DataFrame des résultats
        efficiency_results.append({
            'Scénario': label,
            'Standard (GWh)': total_std,
            'Efficace (GWh)': total_eff,
            'Économies (GWh)': savings_total,
            'Économies (%)': savings_pct_total
        })

# Afficher le tableau récapitulatif
if efficiency_results:
    efficiency_df = pd.DataFrame(efficiency_results)
    display(efficiency_df)

# %% [markdown]
# ## 7. Exportation des résultats
#
# Cette section permet d'exporter les résultats des analyses pour une utilisation ultérieure.

# %%
# Créer un rapport récapitulatif des scénarios simulés
def create_scenarios_summary(scenarios=None):
    """Crée un résumé de tous les scénarios simulés.
    
    Args:
        scenarios: Liste des scénarios à inclure (tous par défaut)
        
    Returns:
        DataFrame avec le résumé des scénarios
    """
    if scenarios is None:
        scenarios = config.future_scenarios.SCENARIOS
    
    summary_data = []
    
    for scenario in scenarios:
        # Extraire l'année du scénario
        year = config.future_scenarios.get_scenario_year(scenario)
        
        # Vérifier si le scénario a été simulé
        results_dir = config.paths['output'].get_simulation_dir(year, scenario)
        provincial_dir = results_dir / 'provincial'
        
        if provincial_dir.exists() and (provincial_dir / 'summary.json').exists():
            # Charger le résumé provincial
            with open(provincial_dir / 'summary.json', 'r') as f:
                summary = json.load(f)
                
            # Extraire les informations importantes
            total_gwh = summary.get('annual_consumption', {}).get('total_gwh', 0)
            
            # Extraire les usages finaux
            end_uses = {}
            for key, value in summary.get('annual_consumption', {}).items():
                if '_kwh' in key and key != 'total_kwh':
                    end_use = key.replace('_kwh', '')
                    end_uses[end_use] = value / 1e6  # Conversion en GWh
            
            # Décomposer le scénario
            parts = scenario.split('_')
            climate_type = parts[1] if len(parts) > 1 else ""
            growth_type = parts[2] if len(parts) > 2 else ""
            efficiency_type = parts[3] if len(parts) > 3 else ""
            
            # Ajouter au résumé
            scenario_summary = {
                'Scénario': scenario,
                'Année': year,
                'Climat': climate_type,
                'Croissance': growth_type,
                'Efficacité': efficiency_type,
                'Consommation (GWh)': total_gwh
            }
            
            # Ajouter les usages finaux
            scenario_summary.update({f"{use} (GWh)": value for use, value in end_uses.items()})
            
            summary_data.append(scenario_summary)
    
    # Créer le DataFrame
    if summary_data:
        return pd.DataFrame(summary_data)
    else:
        return pd.DataFrame()

# Générer et afficher le résumé
scenarios_summary = create_scenarios_summary()
if not scenarios_summary.empty:
    # Trier par année et type de climat
    scenarios_summary = scenarios_summary.sort_values(['Année', 'Climat', 'Croissance', 'Efficacité'])
    display(scenarios_summary)
    
    # Sauvegarder en CSV
    export_path = project_root / 'notebooks' / 'scenario_results_summary.csv'
    scenarios_summary.to_csv(export_path, index=False)
    print(f"Résumé exporté vers: {export_path}")
else:
    print("Aucun scénario simulé trouvé dans les résultats.")

# %%
import os
import shutil
from pathlib import Path

def clean_directories(base_path):
    """
    Parcourt la structure hiérarchique et supprime tous les dossiers
    qui ne s'appellent pas 'mrc' au niveau des sous-dossiers B2.
    
    Args:
        base_path (str): Chemin du dossier de base B
    """
    base_dir = Path(base_path)
    
    # Vérifier que le dossier de base existe
    if not base_dir.is_dir():
        print(f"Le dossier {base_dir} n'existe pas.")
        return
    
    # Parcourir les dossiers de niveau B1
    for b1_dir in base_dir.iterdir():
        if not b1_dir.is_dir():
            continue
            
        print(f"Traitement du dossier B1: {b1_dir.name}")
        
        # Parcourir les dossiers de niveau B2
        for b2_dir in b1_dir.iterdir():
            if not b2_dir.is_dir():
                continue
                
            print(f"  Traitement du dossier B2: {b2_dir.name}")
            
            # Parcourir et supprimer les sous-dossiers qui ne s'appellent pas 'mrc'
            for sub_dir in b2_dir.iterdir():
                if sub_dir.is_dir() and sub_dir.name != "mrc":
                    print(f"    Suppression de: {sub_dir.name}")
                    shutil.rmtree(sub_dir)

if __name__ == "__main__":
    # Remplacez ce chemin par votre dossier B
    base_path = Path(r"C:\PI4\6\residence_quebec\data\outputs\simulations")
    
    # Confirmation avant de commencer
    print(f"Ce script va supprimer tous les dossiers qui ne s'appellent pas 'mrc' "
          f"dans les sous-dossiers de {base_path}.")
    confirmation = "oui"
    
    if confirmation.lower() in ["oui", "o", "yes", "y"]:
        clean_directories(base_path)
        print("Nettoyage terminé.")
    else:
        print("Opération annulée.")
